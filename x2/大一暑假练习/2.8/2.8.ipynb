# %%
import numpy as np

# 构造系数矩阵 A
A = np.zeros((1000, 1000))
for i in range(1000):
    A[i, i] = 4
    if i < 999:
        A[i, i+1] = 1

# 构造常数向量 B
B = np.zeros(1000)


B[0:-1] = np.arange(1, 1000)

# 求解线性方程组
X = np.linalg.solve(A, B)
X
# Out:
# array([1.60000000e-01, 3.60000000e-01, 5.60000000e-01, 7.60000000e-01,
#        9.60000000e-01, 1.16000000e+00, 1.36000000e+00, 1.56000000e+00,
#        1.76000000e+00, 1.96000000e+00, 2.16000000e+00, 2.36000000e+00,
#        2.56000000e+00, 2.76000000e+00, 2.96000000e+00, 3.16000000e+00,
#        3.36000000e+00, 3.56000000e+00, 3.76000000e+00, 3.96000000e+00,
#        4.16000000e+00, 4.36000000e+00, 4.56000000e+00, 4.76000000e+00,
#        4.96000000e+00, 5.16000000e+00, 5.36000000e+00, 5.56000000e+00,
#        5.76000000e+00, 5.96000000e+00, 6.16000000e+00, 6.36000000e+00,
#        6.56000000e+00, 6.76000000e+00, 6.96000000e+00, 7.16000000e+00,
#        7.36000000e+00, 7.56000000e+00, 7.76000000e+00, 7.96000000e+00,
#        8.16000000e+00, 8.36000000e+00, 8.56000000e+00, 8.76000000e+00,
#        8.96000000e+00, 9.16000000e+00, 9.36000000e+00, 9.56000000e+00,
#        9.76000000e+00, 9.96000000e+00, 1.01600000e+01, 1.03600000e+01,
# ...
